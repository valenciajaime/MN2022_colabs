# %% [markdown]
# <a href="https://colab.research.google.com/github/valenciajaime/MN2022_colabs/blob/main/Nuevos/MN_WV_20221_Clase01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Descripcion

# %% [markdown]
# **Objetivos**
#
# Presentacion del desfaces en señales senoidales y su relacion con solucion de sistemas lineales complejos.
#
#
# **Desarrollo**

# %% [markdown]
# # Modulos principales

# %% [markdown]
# Importacion de modulo principales de trabajo en Metodos Numericos.

# %%
import pylab as plt
import matplotlib
import numpy as np
import scipy as SC
import sympy as SP

# %% [markdown]
# Observacion de las versiones de los modulos importados.

# %%
print("Version numpy: ",np.__version__)
print("Version Matplotlib: ",matplotlib.__version__)
print("Version scipy: ", SC.__version__)
print("Version sympy: ",  SP.__version__)
# Out:
# Version numpy:  1.21.6
# Version Matplotlib:  3.2.2
# Version scipy:  1.4.1
# Version sympy:  1.7.1

# %% [markdown]
# # Generar Datos

# %%
x = np.linspace(0,4*np.pi,100)
y1 = np.cos(x)
y2 = np.cos(x+(np.pi/4))
y3 = np.sin(x)

# %% [markdown]
# # Graficar Datos

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)

# %% [markdown]
# # Variables primitivas

# %%
a = 20
print(a, type(a))

b = 34.78
print(b,type(b))

c = "Alfabetico"
print(c,type(c))

d = True
print(d, type(d))

e = None
print(e, type(e))
# Out:
# 20 <class 'int'>
# 34.78 <class 'float'>
# Alfabetico <class 'str'>
# True <class 'bool'>
# None <class 'NoneType'>
