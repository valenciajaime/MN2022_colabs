# %% [markdown]
# <a href="https://colab.research.google.com/github/valenciajaime/MN2022_colabs/blob/main/Nuevos/MN_MJ_20221_Clase02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Portada Presentacion Clase

# %% [markdown]
# **Nombres:**
#
# Esteban Velilla H.
#
# Jaime A. Valencia V.
#
#
# **Email:**
#
# esteban.velilla@udea.edu.co
#
# jalejandro.valencia@udea.edu.co
#
#
# **Curso:**
# Metodos numericos 2022-1
#
# **Fecha:**
# Martes 2022-mayo-31

# %% [markdown]
# # Descripcion

# %% [markdown]
# **Objetivos**
#
# Presentacion del desfaces en señales senoidales y su relacion con solucion de sistemas lineales complejos.
#
#
# **Desarrollo**
#
#
#
# 1.   Desfaces
# 2.   Sistema lineal complejo

# %% [markdown]
# # Modulos principales

# %% [markdown]
# Importacion de modulo principales de trabajo en Metodos Numericos.

# %%
import pylab as plt
import matplotlib
import numpy as np
import scipy as SC
import sympy as SP

# %% [markdown]
# Observacion de las versiones de los modulos importados.

# %%
print("Version numpy: ",np.__version__)
print("Version Matplotlib: ",matplotlib.__version__)
print("Version scipy: ", SC.__version__)
print("Version sympy: ",  SP.__version__)
# Out:
# Version numpy:  1.21.6
# Version Matplotlib:  3.2.2
# Version scipy:  1.4.1
# Version sympy:  1.7.1

# %% [markdown]
# # Desfaces

# %% [markdown]
# [Animacion desfaces en elementos R, L, C: ](https://www.animations.physics.unsw.edu.au/jw/AC.html#animation6)

# %%
#oscilogramas

t = np.arange(0,0.1,1e-3)

f_hz = 60 #Frecuencia(numero de veces que se repite la onda en un seg)

wo = 2*np.pi*f_hz #Frecuencia angular

V_t = 155*np.cos(wo*t) #Onda de voltaje

A_desf = -wo*(3e-3) #Angulo negativo retrazo de la onda
I_t = 44*np.cos(wo*t + A_desf) #onda de corriente desfasada

plt.figure(1)
plt.plot(t,V_t, t, I_t)
plt.legend(["Voltaje","Corriente"])
plt.grid("on")
plt.xlabel("Tiempo(s)")

plt.figure(2)
plt.plot(V_t,I_t)
plt.xlabel("V_t")
plt.ylabel("I_t")

plt.show()

# %% [markdown]
# # Sistema lineal complejo

# %% [markdown]
# ![Fasores_2022-05-26 15-12-06.png](data:image/png;base64,...)

# %% [markdown]
# [Circuitos AC: ](https://www.philadelphia.edu.jo/academics/fobeidat/uploads/Electric%20Circuits%20II%20Course/5%20Phasor%20diagram.pdf)

# %%
#sistema lineal complejo

E =complex(100,0) #Fuente de voltaje
Z1 = complex(4,0) # Rama Resistiva
Z2 = complex(9,-7) # Rama capacitiva
Z3 = complex(8,6) # Rama inductiva

A = np.array([[Z1,Z2],[Z3, -(Z2+Z3)]], dtype = np.complex_)
b = np.array([E,0], dtype = np.complex_)

I = np.linalg.solve(A,b)

print("I: ",I[0])
print("Magnitud I: ",abs(I[0]))
print("Fase I: ",np.angle(I[0],deg=True))
# Out:
# I:  (9.348612786489747-0.2412545235223167j)
# Magnitud I:  9.351725229969045
# Fase I:  -1.4782726566888744

# %% [markdown]
# # Resultados y conclusiones

# %% [markdown]
# **Conclusiones:**
#
#
#
# **Resultados:**
#
# **Referencias:**
#
# [Animacion Desfaces](https://www.philadelphia.edu.jo/academics/fobeidat/uploads/Electric%20Circuits%20II%20Course/5%20Phasor%20diagram.pdf)
#
# [Circuitos AC](https://www.philadelphia.edu.jo/academics/fobeidat/uploads/Electric%20Circuits%20II%20Course/5%20Phasor%20diagram.pdf)
#
#
#
# *Libros*
#
# [Numerical Computing with MATLAB
# Copyright 2004, Cleve Moler. Introd.](https://www.mathworks.com/content/dam/mathworks/mathworks-dot-com/moler/intro.pdf)
#
# [Burde & Faires](https://udeaeduco.sharepoint.com/:b:/s/MtodosNumricos_2022-1/EQd1_32TgMhCh8MBU0FqxpIBSIjxSMEJKAcVIVyvYZHSng?e=nrWw8z)
#
# [Chapra & Canale](https://udeaeduco.sharepoint.com/:b:/s/MtodosNumricos_2022-1/EZgs5MpMDKtLpAZlwGEmn9oB3FvpAGncvlnWPcZ9wRNhIg?e=fPcsyf)
